# %%
import transformers

bert = transformers.BertModel.from_pretrained('bert-base-cased')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [5], in <module>
#       1 import transformers
# ----> 3 bert = transformers.BertModel.from_pretrained('bert-base-cased')
#
# File ~/miniforge3/envs/trans-fat/lib/python3.9/site-packages/transformers/modeling_utils.py:1268, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#    1266 if not isinstance(config, PretrainedConfig):
#    1267     config_path = config if config is not None else pretrained_model_name_or_path
# -> 1268     config, model_kwargs = cls.config_class.from_pretrained(
#    1269         config_path,
#    1270         cache_dir=cache_dir,
#    1271         return_unused_kwargs=True,
#    1272         force_download=force_download,
#    1273         resume_download=resume_download,
#    1274         proxies=proxies,
# ...
